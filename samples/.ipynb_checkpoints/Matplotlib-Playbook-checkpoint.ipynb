# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y, 'r--')
plt.xlabel('XR')
plt.ylabel('YR')
plt.title('FUNCTIONAL PLOT - RED')
# Out:
# Text(0.5, 1.0, 'FUNCTIONAL PLOT - RED')

# %%
plt.plot(y,x, 'g--')
plt.xlabel('XG')
plt.ylabel('YG')
plt.title('FUNCTIONAL PLOT - GREEN')
# Out:
# Text(0.5, 1.0, 'FUNCTIONAL PLOT - GREEN')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.0,0.0,1,1])
axes1.plot(x,y, 'r')
axes1.set_title('LARGE PLOT')

axes2 = fig.add_axes([0.2,0.5,0.2,0.2])
axes2.plot(y,x)
axes2.set_title('SMALL PLOT')
# Out:
# Text(0.5, 1.0, 'SMALL PLOT')

# %%
plt.plot(x,y,'r')
# Out:
# Text(0.5, 1.0, 'FUNCTIONAL PLOT')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y**2, label='X*2')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].legend(loc=0)

axes[1].plot(x,y**3)
axes[1].set_xlabel('X')
axes[1].set_ylabel('Y')

fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4), dpi=100)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_title("Normal scale")

axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)");
